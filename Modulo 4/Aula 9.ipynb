# %% [markdown]
# # Pandas

# %%
import pandas as pd
import os

# %%
diretorio_atual = os.getcwd()
os.chdir(diretorio_atual)

# %%
dados_bp = pd.read_csv('dfp_cia_aberta_BPA_ind_2018.csv')
#erro ocorre

# %%
#arquivos em pradroes brasileiros usam ; como separadores ao invés de ,
#encoding pode variar
dados_bp = pd.read_csv(
    'dfp_cia_aberta_BPA_ind_2018.csv',
    sep= ';',
    encoding = 'ISO-8859-1',
    decimal = ',')

dados_bp
# Out:
#                  CNPJ_CIA    DT_REFER  VERSAO        DENOM_CIA  CD_CVM  \
# 0      00.000.000/0001-91  2018-12-31       2  BCO BRASIL S.A.    1023
# 1      00.000.000/0001-91  2018-12-31       2  BCO BRASIL S.A.    1023
# 2      00.000.000/0001-91  2018-12-31       2  BCO BRASIL S.A.    1023
# 3      00.000.000/0001-91  2018-12-31       2  BCO BRASIL S.A.    1023
# 4      00.000.000/0001-91  2018-12-31       2  BCO BRASIL S.A.    1023
# ...                   ...         ...     ...              ...     ...
# 79309  97.837.181/0001-47  2018-12-31       1       DEXCO S.A.   21091
# 79310  97.837.181/0001-47  2018-12-31       1       DEXCO S.A.   21091
# 79311  97.837.181/0001-47  2018-12-31       1       DEXCO S.A.   21091
# 79312  97.837.181/0001-47  2018-12-31       1       DEXCO S.A.   21091
# 79313  97.837.181/0001-47  2018-12-31       1       DEXCO S.A.   21091
#
#                                        GRUPO_DFP MOEDA ESCALA_MOEDA  \
# ...

# %%
#indexando pela data, filtrando colunas
dados_bp = pd.read_csv(
    'dfp_cia_aberta_BPA_ind_2018.csv',
    sep= ';',
    encoding = 'ISO-8859-1',
    decimal = ',',
    index_col= 'DT_REFER',
    usecols= ['DT_REFER', 'DENOM_CIA', 'ESCALA_MOEDA', 'VL_CONTA'])

dados_bp
# Out:
#                   DENOM_CIA ESCALA_MOEDA               VL_CONTA
# DT_REFER
# 2018-12-31  BCO BRASIL S.A.          MIL  1425212839.0000000000
# 2018-12-31  BCO BRASIL S.A.          MIL  1479378963.0000000000
# 2018-12-31  BCO BRASIL S.A.          MIL   760229569.0000000000
# 2018-12-31  BCO BRASIL S.A.          MIL   827643785.0000000000
# 2018-12-31  BCO BRASIL S.A.          MIL    12349179.0000000000
# ...                     ...          ...                    ...
# 2018-12-31       DEXCO S.A.          MIL           0.0000000000
# 2018-12-31       DEXCO S.A.          MIL        2402.0000000000
# 2018-12-31       DEXCO S.A.          MIL        2402.0000000000
# 2018-12-31       DEXCO S.A.          MIL       25577.0000000000
# 2018-12-31       DEXCO S.A.          MIL           0.0000000000
#
# [79314 rows x 3 columns]

# %%
#exportando dados em csv
dados_bp.to_csv('dados_tratados_cvm.csv', sep= ';')
