# %% [markdown]
# # Pandas

# %%
import pandas as pd
import os

# %%
diretorio_atual = os.getcwd()
os.chdir(diretorio_atual)

# %%
dados_petrobras = pd.read_excel("dados_petro.xlsx") #so funciona pq eu mudei o diretório

dados_petrobras
# Out:
#                   Curso:     Python Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                  Aula:          8        NaN        NaN        NaN
# 1                    NaN        NaN        NaN        NaN        NaN
# 2                    NaN        NaN        NaN        NaN        NaN
# 3                    NaN        NaN        NaN        NaN        NaN
# 4                    NaN        NaN        NaN        NaN        NaN
# ..                   ...        ...        ...        ...        ...
# 123  2023-01-08 00:00:00  36.291226   4.323766  35.336541  37.046481
# 124  2023-01-09 00:00:00  36.389212   4.361382  35.537959  37.346557
# 125  2023-01-10 00:00:00  36.130849   4.325183  35.609035  36.973091
# 126  2023-01-11 00:00:00  36.250081   4.318695  35.395381  37.324336
# 127  2023-01-12 00:00:00         37   5.339415      37.58      38.15
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7   Unnamed: 8   Unnamed: 9 Unnamed: 10  \
# ...

# %%
dados_petrobras = pd.read_excel("dados_petro.xlsx", skiprows=6)
dados_petrobras
# Out:
#           Data Fech Ajustado Variação (%) Fech Histórico  Abertura Ajustado  \
# 0   2022-09-13            nd           nd              nd                nd
# 1   2022-09-14            31    -0.660585           31.58             32.15
# 2   2022-09-15            31    -0.654706       31.412626           32.4072
# 3   2022-09-16       31.2356     -0.65883       31.632514         32.300256
# 4   2022-09-17     30.966974    -0.652835        31.80333         32.597419
# ..         ...           ...          ...             ...               ...
# 117 2023-01-08     36.291226     4.323766       35.336541         37.046481
# 118 2023-01-09     36.389212     4.361382       35.537959         37.346557
# 119 2023-01-10     36.130849     4.325183       35.609035         36.973091
# 120 2023-01-11     36.250081     4.318695       35.395381         37.324336
# 121 2023-01-12            37     5.339415           37.58             38.15
#
# ...
