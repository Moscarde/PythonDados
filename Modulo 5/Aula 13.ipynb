# %% [markdown]
# # MatplotLib

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.ticker as mtick
import matplotlib.dates as mdate
import yfinance as yf
from datetime import datetime

# %%
cotacoes = yf.download(['^BVSP'], '2016-01-01')['Adj Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data_crises =[(datetime(2017, 5, 17), 'Joesley Day'),
              (datetime(2016, 8, 31), 'Impeachment Dilma')]


cotacoes.asof(datetime(2017, 5, 17))


fig, ax = plt.subplots()

ax.plot(cotacoes)

for data, evento in data_crises:
    ax.annotate(
        evento, xy= (data, cotacoes.asof(data) + 2800),
        xytext = (data, cotacoes.asof(data) + 9000),
        arrowprops = dict(facecolor = 'black', headwidth = 4, width = 2, headlength = 4),
        horizontalalignment = 'right', verticalalignment = 'top')

ax.xaxis.set_major_locator(mdate.YearLocator(1))

# %%
fig, ax = plt.subplots()
ax = sns.lineplot(data=cotacoes)
ax.set_title('Valores IBOV x Tempo')

ax.Text(2, 1.5, 'ahahahah')


# for data, evento in data_crises:
#     ax.annotate(
#         evento, xy= (data, cotacoes.asof(data) + 2800),
#         xytext = (data, cotacoes.asof(data) + 9000),
#         arrowprops = dict(facecolor = 'black', headwidth = 4, width = 2, headlength = 4),
#         horizontalalignment = 'right', verticalalignment = 'top')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Gabriel\Python Dados\Modulo 5\Aula 13.ipynb Célula 5 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/Gabriel/Python%20Dados/Modulo%205/Aula%2013.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> ax = sns.lineplot(data=cotacoes)
#       <a href='vscode-notebook-cell:/c%3A/Users/Gabriel/Python%20Dados/Modulo%205/Aula%2013.ipynb#X25sZmlsZQ%3D%3D?line=2'>3</a> ax.set_title('Valores IBOV x Tempo')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Gabriel/Python%20Dados/Modulo%205/Aula%2013.ipynb#X25sZmlsZQ%3D%3D?line=4'>5</a> ax.Text(2, 1.5, 'ahahahah')
#       <a href='vscode-notebook-cell:/c%3A/Users/Gabriel/Python%20Dados/Modulo%205/Aula%2013.ipynb#X25sZmlsZQ%3D%3D?line=7'>8</a> # for data, evento in data_crises:
# ...
