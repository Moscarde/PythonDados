# %% [markdown]
# # MatplotLib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %%
#parametros opcionais para globalizar
params = {
    'ytick.color': 'black',
    'xtick.color': 'black',
    'axes.labelcolor': 'black',
    'axes.edgecolor': 'black'
}
plt.rcParams.update(params)

# %%
fig, ax = plt.subplots()

ax.grid(True)
ax.plot([2, 4, 6], [8, 5, 16])

# %%
fig, ax = plt.subplots(2, 2, figsize = (20, 15))
for i in range(2):
    for j in range(2):
        print(i, j)
        ax[i, j].plot(np.random.random(10))
# Out:
# 0 0
# 0 1
# 1 0
# 1 1

# %%
cotacao_weg = yf.download('WEGE3.SA')['Adj Close']

fig, ax = plt.subplots()
ax.plot(cotacao_weg.index, cotacao_weg.values)

# ===
#cotacao_weg.plot()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
cotacoes = yf.download(['WEGE3.SA', 'PETR4.SA', 'VALE3.SA', 'MGLU3.SA'])['Adj Close'].dropna()

fig, ax = plt.subplots(2, 2, figsize = (20, 7), sharey= True) 
#sharey = compartilha o y ~> achata outros graficos, mantem um padrao

coluna = 0
for i in range(2):
    for j in range(2):
        print(i, j)
        ax[i, j].plot(cotacoes.index, cotacoes.iloc[:, coluna])
        ax[i, j].set_title(cotacoes.columns[coluna])
        coluna += 1
# Out:
# [*********************100%%**********************]  4 of 4 completed
# 0 0
# 0 1
# 1 0
# 1 1

# %%
fig = plt.figure()
#existem outras formas de criar graficos...

# %% [markdown]
# ## Desafios

# %%
fig, ax = plt.subplots()
dict_pontuacao_por_rodada = {
    'pontuacao': [10, 12, 13, 10, 33, 10, 20, 20, 23],
    'rodada': sorted([1, 2, 3, 4, 5, 6, 7, 8, 9] )
}
pontuacao = pd.DataFrame(dict_pontuacao_por_rodada)
pontuacao = pontuacao.set_index('rodada')
pontuacao

ax.grid(True)
ax.plot(pontuacao.index, pontuacao.values)

# %%
acoes = []
for i in range(3):
    acoes.append(str(input('Digite o tick de uma acao').upper()) + '.SA')
acoes
# Out:
# ['MGLU3.SA', 'ASAI3.SA', 'VALE3.SA']

# %%
acoes.append('^BVSP')
dados_acoes = yf.download(acoes)['Adj Close'].dropna()

fig, ax = plt.subplots(2, 2, figsize = (12, 8))

coluna = 0
for i in range(2):
    for j in range(2):
        
        ax[i, j].plot(dados_acoes.index, dados_acoes.iloc[:, coluna])

        if dados_acoes.columns[coluna] == '^BVSP':
            ax[i, j].set_title(dados_acoes.columns[coluna], color = 'green')
        else:
            ax[i, j].set_title(dados_acoes.columns[coluna])
            
        coluna += 1
# Out:
# [*********************100%%**********************]  4 of 4 completed
